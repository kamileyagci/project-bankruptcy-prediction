# %% [markdown]
# # Data Explore

# %% [markdown]
# ## Polish companies bankruptcy data Data Set
#
# https://archive.ics.uci.edu/ml/datasets/Polish+companies+bankruptcy+data
#
# **Abstract:**
#
# The dataset is about bankruptcy prediction of Polish companies.The bankrupt companies were analyzed in the period 2000-2012, while the still operating companies were evaluated from 2007 to 2013.
#
# **Source:**
#
# Creator: Sebastian Tomczak
# -- Department of Operations Research, Wroclaw University of Science and Technology, Poland
#
# Donor: Sebastian Tomczak, Maciej Zieba, Jakub M. Tomczak
#
# **Data Set Information:**
#
# The dataset is about bankruptcy prediction of Polish companies. The data was collected from Emerging Markets Information Service (EMIS, [Web Link]), which is a database containing information on emerging markets around the world. The bankrupt companies were analyzed in the period 2000-2012, while the still operating companies were evaluated from 2007 to 2013.
# Basing on the collected data five classification cases were distinguished, that depends on the forecasting period:
# - 1stYear: the data contains financial rates from 1st year of the forecasting period and corresponding class label that indicates bankruptcy status after 5 years. The data contains 7027 instances (financial statements), 271 represents bankrupted companies, 6756 firms that did not bankrupt in the forecasting period.
# - 2ndYear: the data contains financial rates from 2nd year of the forecasting period and corresponding class label that indicates bankruptcy status after 4 years. The data contains 10173 instances (financial statements), 400 represents bankrupted companies, 9773 firms that did not bankrupt in the forecasting period.
# - 3rdYear: the data contains financial rates from 3rd year of the forecasting period and corresponding class label that indicates bankruptcy status after 3 years. The data contains 10503 instances (financial statements), 495 represents bankrupted companies, 10008 firms that did not bankrupt in the forecasting period.
# - 4thYear: the data contains financial rates from 4th year of the forecasting period and corresponding class label that indicates bankruptcy status after 2 years. The data contains 9792 instances (financial statements), 515 represents bankrupted companies, 9277 firms that did not bankrupt in the forecasting period.
# - 5thYear: the data contains financial rates from 5th year of the forecasting period and corresponding class label that indicates bankruptcy status after 1 year. The data contains 5910 instances (financial statements), 410 represents bankrupted companies, 5500 firms that did not bankrupt in the forecasting period.
#
#
# **Attribute Information:**
#
# * X1 net profit / total assets
# * X2 total liabilities / total assets
# * X3 working capital / total assets
# * X4 current assets / short-term liabilities
# * X5 [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365
# * X6 retained earnings / total assets
# * X7 EBIT / total assets
# * X8 book value of equity / total liabilities
# * X9 sales / total assets
# * X10 equity / total assets
# * X11 (gross profit + extraordinary items + financial expenses) / total assets
# * X12 gross profit / short-term liabilities
# * X13 (gross profit + depreciation) / sales
# * X14 (gross profit + interest) / total assets
# * X15 (total liabilities * 365) / (gross profit + depreciation)
# * X16 (gross profit + depreciation) / total liabilities
# * X17 total assets / total liabilities
# * X18 gross profit / total assets
# * X19 gross profit / sales
# * X20 (inventory * 365) / sales
# * X21 sales (n) / sales (n-1)
# * X22 profit on operating activities / total assets
# * X23 net profit / sales
# * X24 gross profit (in 3 years) / total assets
# * X25 (equity - share capital) / total assets
# * X26 (net profit + depreciation) / total liabilities
# * X27 profit on operating activities / financial expenses
# * X28 working capital / fixed assets
# * X29 logarithm of total assets
# * X30 (total liabilities - cash) / sales
# * X31 (gross profit + interest) / sales
# * X32 (current liabilities * 365) / cost of products sold
# * X33 operating expenses / short-term liabilities
# * X34 operating expenses / total liabilities
# * X35 profit on sales / total assets
# * X36 total sales / total assets
# * X37 (current assets - inventories) / long-term liabilities
# * X38 constant capital / total assets
# * X39 profit on sales / sales
# * X40 (current assets - inventory - receivables) / short-term liabilities
# * X41 total liabilities / ((profit on operating activities + depreciation) * (12/365))
# * X42 profit on operating activities / sales
# * X43 rotation receivables + inventory turnover in days
# * X44 (receivables * 365) / sales
# * X45 net profit / inventory
# * X46 (current assets - inventory) / short-term liabilities
# * X47 (inventory * 365) / cost of products sold
# * X48 EBITDA (profit on operating activities - depreciation) / total assets
# * X49 EBITDA (profit on operating activities - depreciation) / sales
# * X50 current assets / total liabilities
# * X51 short-term liabilities / total assets
# * X52 (short-term liabilities * 365) / cost of products sold)
# * X53 equity / fixed assets
# * X54 constant capital / fixed assets
# * X55 working capital
# * X56 (sales - cost of products sold) / sales
# * X57 (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)
# * X58 total costs /total sales
# * X59 long-term liabilities / equity
# * X60 sales / inventory
# * X61 sales / receivables
# * X62 (short-term liabilities *365) / sales
# * X63 sales / short-term liabilities
# * X64 sales / fixed assets

# %% [markdown]
# ## Load Libraries

# %%
# Import base libraries
import pandas as pd
from scipy.io import arff
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
# Load all five data files

data1 = arff.loadarff('data/1year.arff')
df1 = pd.DataFrame(data1[0])

data2 = arff.loadarff('data/2year.arff')
df2 = pd.DataFrame(data2[0])

data3 = arff.loadarff('data/3year.arff')
df3 = pd.DataFrame(data3[0])

data4 = arff.loadarff('data/4year.arff')
df4 = pd.DataFrame(data4[0])

data5 = arff.loadarff('data/5year.arff')
df5 = pd.DataFrame(data5[0])

# %%
# Size of datasets

print('Size of datasets')
print("Data 1 (Year1):", len(df1))
print("Data 2 (Year2):", len(df2))
print("Data 3 (Year3):", len(df3))
print("Data 4 (Year4):", len(df4))
print("Data 5 (Year5):", len(df5))
# Out:
# Size of datasets
# Data 1 (Year1): 7027
# Data 2 (Year2): 10173
# Data 3 (Year3): 10503
# Data 4 (Year4): 9792
# Data 5 (Year5): 5910

# %%
# Data 1, first five rows
df3.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7   Attr8  \
# 0  0.174190  0.41299  0.14371  1.3480 -28.9820  0.60383  0.219460  1.1225
# 1  0.146240  0.46038  0.28230  1.6294   2.5952  0.00000  0.171850  1.1721
# 2  0.000595  0.22612  0.48839  3.1599  84.8740  0.19114  0.004572  2.9881
# 3  0.024526  0.43236  0.27546  1.7833 -10.1050  0.56944  0.024526  1.3057
# 4  0.188290  0.41504  0.34231  1.9279 -58.2740  0.00000  0.233580  1.4094
#
#     Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  Attr60  \
# 0  1.1961  0.46359  ...  0.163960  0.375740  0.83604  0.000007  9.7145
# 1  1.6018  0.53962  ...  0.027516  0.271000  0.90108  0.000000  5.9882
# 2  1.0077  0.67566  ...  0.007639  0.000881  0.99236  0.000000  6.7742
# 3  1.0509  0.56453  ...  0.048398  0.043445  0.95160  0.142980  4.2286
# 4  1.3393  0.58496  ...  0.176480  0.321880  0.82635  0.073039  2.5912
#
#    Attr61   Attr62  Attr63  Attr64  class
# 0  6.2813   84.291  4.3303  4.0341   b'0'
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10503 entries, 0 to 10502
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Attr1   10503 non-null  float64
#  1   Attr2   10503 non-null  float64
#  2   Attr3   10503 non-null  float64
#  3   Attr4   10485 non-null  float64
#  4   Attr5   10478 non-null  float64
#  5   Attr6   10503 non-null  float64
#  6   Attr7   10503 non-null  float64
#  7   Attr8   10489 non-null  float64
#  8   Attr9   10500 non-null  float64
#  9   Attr10  10503 non-null  float64
#  10  Attr11  10503 non-null  float64
#  11  Attr12  10485 non-null  float64
#  12  Attr13  10460 non-null  float64
#  13  Attr14  10503 non-null  float64
#  14  Attr15  10495 non-null  float64
#  15  Attr16  10489 non-null  float64
#  16  Attr17  10489 non-null  float64
#  17  Attr18  10503 non-null  float64
#  18  Attr19  10460 non-null  float64
#  19  Attr20  10460 non-null  float64
# ...

# %%
df3.describe()
# Out:
#               Attr1         Attr2         Attr3         Attr4         Attr5  \
# count  10503.000000  10503.000000  10503.000000  10485.000000  1.047800e+04
# mean       0.052844      0.619911      0.095490      9.980499 -1.347662e+03
# std        0.647797      6.427041      6.420056    523.691951  1.185806e+05
# min      -17.692000      0.000000   -479.730000      0.002080 -1.190300e+07
# 25%        0.000686      0.253955      0.017461      1.040100 -5.207075e+01
# 50%        0.043034      0.464140      0.198560      1.605600  1.579300e+00
# 75%        0.123805      0.689330      0.419545      2.959500  5.608400e+01
# max       52.652000    480.730000     17.708000  53433.000000  6.854400e+05
#
#               Attr6         Attr7         Attr8         Attr9        Attr10  \
# count  10503.000000  10503.000000  10489.000000  10500.000000  10503.000000
# mean      -0.121159      0.065624     19.140113      1.819254      0.366093
# ...

# %% [markdown]
# ### Change the label/class dytpe

# %%
# Class
df3['class'].unique()
# Out:
# array([b'0', b'1'], dtype=object)

# %%
# Convert class/label type to binary

df1['class'] = df1['class'].astype('int64')
df2['class'] = df2['class'].astype('int64')
df3['class'] = df3['class'].astype('int64')
df4['class'] = df4['class'].astype('int64')
df5['class'] = df5['class'].astype('int64')

# %%
df3['class'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ### Check class distribution

# %%
# Class Distribution

df3['class'].value_counts(normalize=True)

df_list = [df1, df2, df3, df4, df5]

for i, df in enumerate(df_list, start=1):
    val_counts = df['class'].value_counts()
    print(f'Data {i}:')
    print('Total:', len(df))
    print(val_counts, '\n-------\n')
# Out:
# Data 1:
# Total: 7027
# 0    6756
# 1     271
# Name: class, dtype: int64
# -------
#
# Data 2:
# Total: 10173
# 0    9773
# 1     400
# Name: class, dtype: int64
# -------
#
# Data 3:
# Total: 10503
# 0    10008
# 1      495
# Name: class, dtype: int64
# -------
#
# Data 4:
# Total: 9792
# 0    9277
# 1     515
# Name: class, dtype: int64
# -------
#
# Data 5:
# Total: 5910
# 0    5500
# 1     410
# Name: class, dtype: int64
# -------

# %% [markdown]
# ## Visualizations

# %%
# Scatter Graphs

plt.figure(figsize=(20, 50)) 

for i, col in enumerate(df3.columns, start=1):
    plt.subplot(13, 5, i)
    plt.scatter(df3[col], df3['class'], alpha=0.1)
    plt.title(col)

plt.savefig('figures/scatter_d3.png')

# %%
# Histograms

plt.figure(figsize=(20, 50)) 

for i, col in enumerate(df3.columns, start=1):
    plt.subplot(13, 5, i)
    plt.hist(df3[col], bins=100, log=True)
    plt.title(col)
    
plt.savefig('figures/hist_d3_log.png')

# %%
# Box plots

plt.figure(figsize=(20, 50)) 

for i, col in enumerate(df3.columns, start=1):
    plt.subplot(13, 5, i)
    plt.boxplot(df3[col].dropna()) 
    plt.title(col)

plt.savefig('figures/boxPlot_d3.png')

## Boxplot only draws the attribute only when missing entries removed.

# %% [markdown]
# # Important ! ! ! ! !
#
# **The rest of the file is for handling missing files and removing outliers.**
#
# **I saved the processed data in '_noMiss.csv' and '_noMiss_noOut.csv' files.**
#
# **When I tried to use these cleaned datasets in my analysis, model performance was low. Therefore I didn't use them.**
#
# **XBGoost Classifier can handle missing values and outliers.**

# %% [markdown]
# ## Missing values
# The summary at the end of the sections explains the steps for handling missing values.

# %%
# Check to see if there is any missin label in any dataset

print("# of Missing labels for each dataset")
print('data1', df1['class'].isnull().sum())
print('data2', df2['class'].isnull().sum())
print('data3', df3['class'].isnull().sum())
print('data4', df4['class'].isnull().sum())
print('data5', df5['class'].isnull().sum())
# Out:
# # of Missing labels for each dataset
# data1 0
# data2 0
# data3 0
# data4 0
# data5 0

# %%
# Count the number of rows with at least one missing value

print('Number of rows with at least one missing value:\n')

data = [df1, df2, df3, df4, df5]

for i, df in enumerate(data, start=1):
    miss_count_rows = df.isna().any(axis=1).sum()
    perc = round((miss_count_rows / len(df))*100, 2)
    print(f'data {i}: {miss_count_rows} ({perc}% of data)')
# Out:
# Number of rows with at least one missing value:
#
# data 1: 3833 (54.55% of data)
# data 2: 6085 (59.82% of data)
# data 3: 5618 (53.49% of data)
# data 4: 5023 (51.3% of data)
# data 5: 2879 (48.71% of data)

# %% [markdown]
# ### Remove attributes with high missing values

# %%
# Sort attributes with maximum missing values in data1
df1.isna().sum().sort_values(ascending=False)[0:20]
# Out:
# Attr37    2740
# Attr21    1622
# Attr27     311
# Attr60     135
# Attr45     134
# Attr24     124
# Attr41      84
# Attr11      39
# Attr32      38
# Attr28      34
# Attr64      34
# Attr54      34
# Attr53      34
# Attr46      31
# Attr33      30
# Attr40      30
# Attr63      30
# Attr12      30
# Attr4       30
# Attr52      29
# dtype: int64

# %%
# Sort attributes with maximum missing values in data3
df3.isna().sum().sort_values(ascending=False)[0:20]
# Out:
# Attr37    4736
# Attr21     807
# Attr27     715
# Attr60     592
# Attr45     591
# Attr54     228
# Attr64     228
# Attr53     228
# Attr28     228
# Attr24     227
# Attr41     202
# Attr32     101
# Attr52      86
# Attr47      86
# Attr39      43
# Attr43      43
# Attr30      43
# Attr44      43
# Attr31      43
# Attr42      43
# dtype: int64

# %%
#List the attribute names with maximum missing according to data 3
columns_with_most_missing = list(df3.isna().sum().sort_values(ascending=False)[0:20].index)
columns_with_most_missing
# Out:
# ['Attr37',
#  'Attr21',
#  'Attr27',
#  'Attr60',
#  'Attr45',
#  'Attr54',
#  'Attr64',
#  'Attr53',
#  'Attr28',
#  'Attr24',
#  'Attr41',
#  'Attr32',
#  'Attr52',
#  'Attr47',
#  'Attr39',
#  'Attr43',
#  'Attr30',
#  'Attr44',
#  'Attr31',
#  'Attr42']

# %%
# Create a dataframe of missing values for attributes with max missing

most_missing_df = pd.DataFrame()

for i, df in enumerate(data, start=1):
    numMiss = df[columns_with_most_missing].isna().sum()
    most_missing_df[f'data{i}'] = numMiss

most_missing_df
# Out:
#         data1  data2  data3  data4  data5
# Attr37   2740   4518   4736   4442   2548
# Attr21   1622   3164    807    158    103
# Attr27    311    706    715    641    391
# Attr60    135    543    592    614    268
# Attr45    134    541    591    613    268
# Attr54     34    212    228    231    107
# Attr64     34    212    228    231    107
# Attr53     34    212    228    231    107
# Attr28     34    212    228    231    107
# Attr24    124    225    227    211    135
# Attr41     84    197    202    187     84
# Attr32     38     87    101     96     46
# Attr52     29     74     86     76     36
# Attr47     29     74     86     73     35
# Attr39      0     63     43     21      0
# Attr43      0     63     43     21      0
# Attr30      0     63     43     21      0
# Attr44      0     63     43     21      0
# Attr31      0     63     43     21      0
# Attr42      0     63     43     21      0

# %%
# Delete 14 columns with max missing values

columns_to_delete = columns_with_most_missing[0:14]

print('Columns to delete:\n', columns_to_delete)

df1_rmAtt = df1.drop(columns_to_delete, axis=1)
df2_rmAtt = df2.drop(columns_to_delete, axis=1)
df3_rmAtt = df3.drop(columns_to_delete, axis=1)
df4_rmAtt = df4.drop(columns_to_delete, axis=1)
df5_rmAtt = df5.drop(columns_to_delete, axis=1)
# Out:
# Columns to delete:
#  ['Attr37', 'Attr21', 'Attr27', 'Attr60', 'Attr45', 'Attr54', 'Attr64', 'Attr53', 'Attr28', 'Attr24', 'Attr41', 'Attr32', 'Attr52', 'Attr47']

# %%
df3.shape
# Out:
# (10503, 65)

# %%
df3_rmAtt.shape
# Out:
# (10503, 51)

# %%
# Count the Number of rows with at least one missing value after the removal of 14 columns

print('Number of rows with at least one missing value after the removal of 14 columns:\n')

data_rmAtt = [df1_rmAtt, df2_rmAtt, df3_rmAtt, df4_rmAtt, df5_rmAtt]

for i, df in enumerate(data_rmAtt, start=1):
    miss_count_rows = df.isna().any(axis=1).sum()
    perc = round((miss_count_rows / len(df))*100, 2)
    print(f'data {i}: {miss_count_rows} ({perc}% of data)')
# Out:
# Number of rows with at least one missing value after the removal of 14 columns:
#
# data 1: 80 (1.14% of data)
# data 2: 108 (1.06% of data)
# data 3: 94 (0.89% of data)
# data 4: 100 (1.02% of data)
# data 5: 43 (0.73% of data)

# %%
# Count the total Number of missing values in each dataset, after attribute removal

print('Total Number of missing values in each dataset, after attribute removal:\n')

data_rmAtt = [df1_rmAtt, df2_rmAtt, df3_rmAtt, df4_rmAtt, df5_rmAtt]

for i, df in enumerate(data_rmAtt, start=1):
    miss_count = df.isna().sum().sum()
    perc = round((miss_count / len(df))*100, 2) 
    print(f'data {i}: {miss_count} ({perc}% of total)')
# Out:
# Total Number of missing values in each dataset, after attribute removal:
#
# data 1: 453 (6.45% of total)
# data 2: 1180 (11.6% of total)
# data 3: 833 (7.93% of total)
# data 4: 741 (7.57% of total)
# data 5: 324 (5.48% of total)

# %% [markdown]
# ### Drop rows with high missing values

# %%
# Remove the rows with more than 3 missing data

miss_limit = 4
df1_drRow = df1_rmAtt[df1_rmAtt.isnull().sum(axis=1) < miss_limit]
df2_drRow = df2_rmAtt[df2_rmAtt.isnull().sum(axis=1) < miss_limit]
df3_drRow = df3_rmAtt[df3_rmAtt.isnull().sum(axis=1) < miss_limit]
df4_drRow = df4_rmAtt[df4_rmAtt.isnull().sum(axis=1) < miss_limit]
df5_drRow = df5_rmAtt[df5_rmAtt.isnull().sum(axis=1) < miss_limit]

# %%
df3_rmAtt.shape
# Out:
# (10503, 51)

# %%
df3_drRow.shape
# Out:
# (10445, 51)

# %%
# Count the Number of rows with at least one missing value, after attribute removal, after rows dropped

print('Number of rows with at least one missing value, after attribute removal, after rows dropped:\n')

data_drRow = [df1_drRow, df2_drRow, df3_drRow, df4_drRow, df5_drRow]

for i, df in enumerate(data_drRow, start=1):
    miss_count_rows = df.isna().any(axis=1).sum()
    perc = round((miss_count_rows / len(df))*100, 2)
    print(f'data {i}: {miss_count_rows} ({perc}% of data)')
# Out:
# Number of rows with at least one missing value, after attribute removal, after rows dropped:
#
# data 1: 48 (0.69% of data)
# data 2: 30 (0.3% of data)
# data 3: 36 (0.34% of data)
# data 4: 37 (0.38% of data)
# data 5: 21 (0.36% of data)

# %%
# Count the total Number of missing values in each dataset, after attribute removal, after rows dropped

print('Total Number of missing values, after attribute removal, after rows dropped:\n')

for i, df in enumerate(data_drRow, start=1):
    miss_count = df.isna().sum().sum()
    perc = round((miss_count / len(df))*100, 2) 
    print(f'data {i}: {miss_count} ({perc}% of total)')
# Out:
# Total Number of missing values, after attribute removal, after rows dropped:
#
# data 1: 48 (0.69% of total)
# data 2: 31 (0.31% of total)
# data 3: 36 (0.34% of total)
# data 4: 39 (0.4% of total)
# data 5: 21 (0.36% of total)

# %% [markdown]
# ### Remove two more attitudes: 'Attr5', and 'Attr61'

# %%
columns_with_most_missing2 = list(df1_drRow.isna().sum().sort_values(ascending=False)[0:10].index)
columns_with_most_missing2

most_missing_df2 = pd.DataFrame()

for i, df in enumerate(data_drRow, start=1):
    numMiss = df[columns_with_most_missing2].isna().sum()
    most_missing_df2[f'data{i}'] = numMiss

most_missing_df2
# Out:
#         data1  data2  data3  data4  data5
# Attr11     36      0      0      0      0
# Attr5       8     17     21     21     11
# Attr61      3      9     15     15     10
# Attr46      1      0      0      0      0
# Attr13      0      0      0      0      0
# Attr23      0      0      0      0      0
# Attr22      0      0      0      0      0
# Attr20      0      0      0      0      0
# Attr19      0      1      0      0      0
# Attr18      0      0      0      0      0

# %%
# Delete 2 columns: 'Attr5', 'Attr61'

columns_to_delete2 = ['Attr5', 'Attr61']

df1_rmAtt2 = df1_drRow.drop(columns_to_delete2, axis=1)
df2_rmAtt2 = df2_drRow.drop(columns_to_delete2, axis=1)
df3_rmAtt2 = df3_drRow.drop(columns_to_delete2, axis=1)
df4_rmAtt2 = df4_drRow.drop(columns_to_delete2, axis=1)
df5_rmAtt2 = df5_drRow.drop(columns_to_delete2, axis=1)

# %%
# Count the total Number of missing values in each dataset, after double attribute removal, after rows dropped

print('Total Number of missing values, after double attribute removal, after rows dropped:\n')

data_rmAtt2 = [df1_rmAtt2, df2_rmAtt2, df3_rmAtt2, df4_rmAtt2, df5_rmAtt2]

for i, df in enumerate(data_rmAtt2, start=1):
    miss_count = df.isna().sum().sum()
    perc = round((miss_count / len(df))*100, 2) 
    print(f'data {i}: {miss_count} ({perc}% of total)')
# Out:
# Total Number of missing values, after double attribute removal, after rows dropped:
#
# data 1: 37 (0.53% of total)
# data 2: 5 (0.05% of total)
# data 3: 0 (0.0% of total)
# data 4: 3 (0.03% of total)
# data 5: 0 (0.0% of total)

# %%
df3_drRow.shape
# Out:
# (10445, 51)

# %%
df3_rmAtt2.shape
# Out:
# (10445, 49)

# %% [markdown]
# ### Fill missing values with 'median'

# %%
# Fill missing values with median

df1_noMiss = df1_rmAtt2.fillna(df1_rmAtt2.median())
df2_noMiss = df2_rmAtt2.fillna(df2_rmAtt2.median())
df3_noMiss = df3_rmAtt2.fillna(df3_rmAtt2.median())
df4_noMiss = df4_rmAtt2.fillna(df4_rmAtt2.median())
df5_noMiss = df5_rmAtt2.fillna(df5_rmAtt2.median())

# %%
# Count the total Number of missing values in each dataset, after attribute removal, after rows dropped, after fillna

print('Total Number of missing values, after attribute removal, after rows dropped, after fillna:\n')

data_noMiss = [df1_noMiss, df2_noMiss, df3_noMiss, df4_noMiss, df5_noMiss]

for i, df in enumerate(data_noMiss, start=1):
    miss_count = df.isna().sum().sum()
    perc = round((miss_count / len(df))*100, 2) 
    print(f'data {i}: {miss_count} ({perc}% of total)')
# Out:
# Total Number of missing values, after attribute removal, after rows dropped, after fillna:
#
# data 1: 0 (0.0% of total)
# data 2: 0 (0.0% of total)
# data 3: 0 (0.0% of total)
# data 4: 0 (0.0% of total)
# data 5: 0 (0.0% of total)

# %%
df3.shape
# Out:
# (10503, 65)

# %%
df3_noMiss.shape
# Out:
# (10445, 49)

# %%
# Size of datasets after handling missing values

print('Size of datasets')

i=1
for (df, df_raw) in zip(data_noMiss, data):
    len_nomiss = len(df)
    perc = round((len_nomiss/len(df_raw)) * 100, 2)
    print(f'data {i}: {len_nomiss} ({perc}% of raw data)')
    i = i+1
# Out:
# Size of datasets
# data 1: 6995 (99.54% of raw data)
# data 2: 10095 (99.23% of raw data)
# data 3: 10445 (99.45% of raw data)
# data 4: 9729 (99.36% of raw data)
# data 5: 5888 (99.63% of raw data)

# %% [markdown]
# ### Save data

# %%
df1_noMiss.to_csv('data/data1_noMiss.csv', index=False)
df2_noMiss.to_csv('data/data2_noMiss.csv', index=False)
df3_noMiss.to_csv('data/data3_noMiss.csv', index=False)
df4_noMiss.to_csv('data/data4_noMiss.csv', index=False)
df5_noMiss.to_csv('data/data5_noMiss.csv', index=False)

# %% [markdown]
# ### Summary
#
# In raw data:
# * there are 64 attributes,
# * about 50% of the rows had at least one missing value.
#
# I followed the follwoing steps to handle missing values:
#
# 1. Remove 14 attributes with max missing values: ['Attr37', 'Attr21', 'Attr27', 'Attr60', 'Attr45', 'Attr54', 'Attr64', 'Attr53', 'Attr28', 'Attr24', 'Attr41', 'Attr32', 'Attr52', 'Attr47']
#
# 2. Drop rows with more than 3 missing values. About 0.5% of the rows are removed.
#
# 3. Remove 2 more attributes, ['Attr5', 'Attr61'], which has many missing values. As a resuly 45 missing values left on all five datesets.
#
# 4. Fill the 45 missing values with 'median'
#
# After handling of missing values:
# * 48 attributes left
# * About 0.5% of the rows removed

# %% [markdown]
# ## Outliers
#
# Explore the questions:
#
# 1. What will be the criteria to remove outliers?
# 2. Which variables I will use to remove outliers? One, several, all?
#
# The summary at the end of the section answers the questions.

# %%
#Heatmap to see correlations

plt.figure(figsize=(20,18))
sns.heatmap(df3_noMiss.corr(), center=0);
plt.savefig('figures/heatMap_d3.png')

# %%
# List the attributes in order of correlation with other attributes
np.abs(df3_noMiss.corr()).sum().sort_values(ascending=False)[:15]
# Out:
# Attr1     11.326772
# Attr14    11.315700
# Attr7     11.311064
# Attr11    11.105860
# Attr51    10.583492
# Attr38    10.554339
# Attr3     10.553757
# Attr2     10.546330
# Attr10    10.536663
# Attr25    10.482116
# Attr6     10.452028
# Attr23     8.655922
# Attr19     8.638768
# Attr22     8.530155
# Attr18     8.286663
# dtype: float64

# %%
plt.figure(figsize=(20, 40)) 

for i, col in enumerate(atts, start=1):
    plt.subplot(10, 5, i)
    plt.scatter(df3_noMiss[col], df3_noMiss['class'], alpha=0.1)
    plt.title(col)

plt.show()
plt.savefig('figures/scatter_noMiss_d3.png')

# %%
plt.figure(figsize=(20, 40)) 

for i, col in enumerate(atts, start=1):
    plt.subplot(10, 5, i)
    plt.hist(df3_noMiss[col], bins=100, log=True)
    plt.title(col)
    
plt.show()
plt.savefig('figures/hist_noMiss_d3_log.png')

# %%
# Box plots

atts = df3_noMiss.columns[:-1]

plt.figure(figsize=(20, 40)) 

for i, col in enumerate(atts, start=1):
    plt.subplot(10, 5, i)
    plt.boxplot(df3_noMiss[col])
    plt.title(col)

plt.savefig('figures/boxPlot_noMiss_d3.png')

# %%
def explore_outliers(dfTitle, df, att, c=1.5):
    
    Q3 = np.quantile(df[att], 0.75)
    Q1 = np.quantile(df[att], 0.25)
    IQR = Q3 - Q1
    lower_range = Q1 - c * IQR
    upper_range = Q3 + c * IQR

    print('Quantile statistics:')
    print('Q3:', Q3)
    print('Q1:', Q1)
    print('IQR:', IQR)
    print('Median', np.median(df[att]))
    print('Low:', lower_range)
    print('Up:', upper_range)

    print('---------------')
    print('Graphs before removal:')
    plt.figure(figsize=(20, 6))
    plt.subplot(1, 2, 1)
    plt.boxplot(df[att])
    plt.title(f'{att}, No Missing Dat', fontsize=14)
    plt.subplot(1, 2, 2)
    plt.hist(df[att], bins=100, log=True, label=f'Data size: {len(df)}')
    plt.title(f'{att}, No Missing Data', fontsize=14)
    plt.legend(fontsize=14)
    plt.show()
    
    
    df_rm = df.loc[(df[att]>lower_range) & (df[att]<upper_range)]
    
    print(f"Data Size after outliers removed: {len(df_rm)} (%{round(len(df_rm)/len(df)*100, 2)} of data)")
    
    print('---------------')
    print('Graphs after removal:')
    plt.figure(figsize=(20, 6))
    plt.subplot(1, 2, 1)
    plt.boxplot(df_rm[att])
    plt.title(f'{att}, No Missing Data, Outliers removed', fontsize=14)
    plt.subplot(1, 2, 2)
    plt.hist(df_rm[att], bins=100, log=True, label=f'Data size: {len(df_rm)}')
    plt.title(f'{att}, No Missing Data, Outliers removed', fontsize=14)
    plt.legend(fontsize=14)
    plt.show()
    
    plt.savefig(f'figures/box-hist_{att}_c{c}_{dfTitle}.png')

# %%
explore_outliers('df3_noMiss', df3_noMiss, 'Attr1', 1.5)
# Out:
# Quantile statistics:
# Q3: 0.12411
# Q1: 0.0009227
# IQR: 0.1231873
# Median 0.043321
# Low: -0.18385825
# Up: 0.30889095
# ---------------
# Graphs before removal:
# Data Size after outliers removed: 9198 (%88.06 of data)
# ---------------
# Graphs after removal:

# %%
explore_outliers('df3_noMiss', df3_noMiss, 'Attr1', 3)
# Out:
# Quantile statistics:
# Q3: 0.12411
# Q1: 0.0009227
# IQR: 0.1231873
# Median 0.043321
# Low: -0.3686392
# Up: 0.4936719
# ---------------
# Graphs before removal:
# Data Size after outliers removed: 9981 (%95.56 of data)
# ---------------
# Graphs after removal:

# %%
#Function to remove outliers

def removeOutliers(dataNum, df, cols, c=1.5):
    
    Q1 = df[cols].quantile(0.25)
    Q3 = df[cols].quantile(0.75)
    IQR = Q3 - Q1
 
    lower_range = Q1 - c * IQR
    upper_range = Q3 + c * IQR
    
    drop_index = df[( (df[cols]<lower_range) | (df[cols]>upper_range) ).any(axis=1)].index
    df_filtered = df.drop(drop_index, axis=0)
    
    #print(len(drop_index))
    #print(f"Data {dataNum}: {len(df_filtered)} (%{round(len(df_filtered)/len(df)*100, 2)} of data)")
    
    return df_filtered

# %%
# Remove outliers by filtering Attr1

cols_select=['Attr1']
c=1.5
df3_noOut_sf = removeOutliers(3, df3_noMiss, cols_select, c)
print(df3_noOut_sf.shape)
df3_noOut_sf.hist(bins=100, figsize=(20, 30), log=True)
plt.savefig('figures/hist_f-Attr1_d3_log_c1.5.png')
# Out:
# (9198, 49)

# %%
#Remove outliers for all datasets
#cols_select=['Attr1']
#cols_select=['Attr1', 'Attr7', 'Attr14']
cols_select = atts
c=50

df1_noOut = removeOutliers(1, df1_noMiss, cols_select, c)
df2_noOut = removeOutliers(2, df2_noMiss, cols_select, c)
df3_noOut = removeOutliers(3, df3_noMiss, cols_select, c)
df4_noOut = removeOutliers(4, df4_noMiss, cols_select, c)
df5_noOut = removeOutliers(5, df5_noMiss, cols_select, c)

# %%
df3_noMiss.shape
# Out:
# (10445, 49)

# %%
df3_noOut.shape
# Out:
# (9994, 49)

# %%
print('Size of datasets')

data_noOut = [df1_noOut, df2_noOut, df3_noOut, df4_noOut, df5_noOut]

i=1
for (df, df_noMiss, df_raw) in zip(data_noOut, data_noMiss, data):
    len_noOut = len(df)
    perc = round((len_noOut/len(df_noMiss)) * 100, 2)
    perc2 = round((len_noOut/len(df_raw)) * 100, 2)
    print(f'data {i}: {len_noOut} ({perc}% of No-Missing data  & {perc2}% of Raw data )')
    i = i+1
# Out:
# Size of datasets
# data 1: 6824 (97.56% of No-Missing data  & 97.11% of Raw data )
# data 2: 9673 (95.82% of No-Missing data  & 95.09% of Raw data )
# data 3: 9994 (95.68% of No-Missing data  & 95.15% of Raw data )
# data 4: 9271 (95.29% of No-Missing data  & 94.68% of Raw data )
# data 5: 5670 (96.3% of No-Missing data  & 95.94% of Raw data )

# %%
plt.figure(figsize=(20, 40)) 

for i, col in enumerate(atts, start=1):
    plt.subplot(10, 5, i)
    plt.hist(df3_noOut[col], bins=100, log=False)
    plt.title(col)
    
plt.show()
plt.savefig('figures/hist_noOut_d3.png')

# %%
plt.figure(figsize=(20, 40)) 

for i, col in enumerate(atts, start=1):
    plt.subplot(10, 5, i)
    plt.hist(df3_noOut[col], bins=100, log=True)
    plt.title(col)
    
plt.show()
plt.savefig('figures/hist_noOut_d3_log.png')

# %%
plt.figure(figsize=(20, 40)) 

for i, col in enumerate(atts, start=1):
    plt.subplot(10, 5, i)
    plt.boxplot(df3_noOut[col])
    plt.title(col)

plt.show()
plt.savefig('figures/boxPlot_noOut_d3.png')

# %%
plt.figure(figsize=(20, 40)) 

for i, col in enumerate(atts, start=1):
    plt.subplot(10, 5, i)
    plt.scatter(df3_noOut[col], df3_noOut['class'], alpha=0.1)
    plt.title(col)

plt.show()
plt.savefig('figures/scatter_noOut_d3.png')

# %% [markdown]
# ### Save data

# %%
df1_noOut.to_csv('data/data1_noMiss_noOut.csv', index=False)
df2_noOut.to_csv('data/data2_noMiss_noOut.csv', index=False)
df3_noOut.to_csv('data/data3_noMiss_noOut.csv', index=False)
df4_noOut.to_csv('data/data4_noMiss_noOut.csv', index=False)
df5_noOut.to_csv('data/data5_noMiss_noOut.csv', index=False)

# %% [markdown]
# ### Summary
#
# * Initially, I plan to use few selected attributes to filter based on IQR. However, it wasn't much effective. The correlation is low between the attributes, filtering on selected variables didn't remove the outliers on other variables.
# * There is also no clear pattern between 'class' and attributes, according to scatter plot. The outliers belong both classes (0 and 1) on almost all attitudes. The few attributes are not clear.
# * The outliers on the data are determined using all attributes, not just few. The filtering is applied on each attribute.
# * The quantiles are used to identify and remove the outliers
#     * lower_range = Q1 - 50 * IQR
#     * upper_range = Q3 + 50 * IQR
# * Even though, 1.5 * IQR is the recommended range for outlier removal, I choose to use 50 * IQR since I am filtering on all 48 variables.
# * Around 5% of the data is classified as outliers and removed.

# %% [markdown]
# ## Check Class Imbalance

# %%
# Class distribution of raw data
print('Raw data')
df3['class'].value_counts(normalize=True)
# Out:
# Raw data
# 0    0.952871
# 1    0.047129
# Name: class, dtype: float64

# %%
# Class distribution after handling of missing data
print('After missing values handles')
df3_noMiss['class'].value_counts(normalize=True)
# Out:
# After missing values handles
# 0    0.952992
# 1    0.047008
# Name: class, dtype: float64

# %%
# Class distribution after removal of outliers and missing data
print('After missing values handles and outliers removed')
df3_noOut['class'].value_counts(normalize=True)
# Out:
# After missing values handles and outliers removed
# 0    0.953372
# 1    0.046628
# Name: class, dtype: float64

# %%
### Class distribution of removed outliers

df = df3_noMiss.copy()
#cols = ['Attr1']
cols = atts
c= 50

Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1
 
lower_range = Q1 - c * IQR
upper_range = Q3 + c * IQR
    
drop_index = df[( (df[cols]<lower_range) | (df[cols]>upper_range) ).any(axis=1)].index
#print(drop_index) 
    
df_outliers = df.loc[drop_index]

print('Outliers')
df_outliers['class'].value_counts(normalize=True)
# Out:
# Outliers
# 0    0.944568
# 1    0.055432
# Name: class, dtype: float64

# %% [markdown]
# ### Summary
#
# The class distrubution of the outliers is a bit different compared to the whole data.
#
# In data 3, the bankruptcy, class=1:
# * 4.71% in raw data
# * 4.70% after missing values handled
# * 4.66% after outliers removed and missing values handled
# * 5.54% in outliers
